# %% [markdown]
# Acquire transaction dataset
# ==============
#
#
# I start this project by searching for some online open dataset related to bank transaction. Unfortunately, I was not able find an available dataset ready to use. It was not a suprise given that bank transactions are highly sensitive data. Therefore, as a starting point, I decided to used my own bank transactions from the last two years. First of all, I need to find a secure way to extract my transaction programmaly and can be easily automated. Here are some options I found through internet.
#
#
# **Third Party Aggregator - developer API：**
# There are a number of bank/investment account data providers, these company request bank transaction data on behalf of their users. Most of these providers untilize some combination of direct bank access (for large institutions) and screen scraping (for institution don't have or provide directly access). The services I looked into were Yodlee, Intuit, MX and Plaid. Among which, Yodlee apears to mostly widely used provider. It provides a free developer sandbox access with update to 5 live users. Plaid, on the other hand, is a newer provider. The also provide free developer access, with connections available for up to 100 live accounts, which certainly sounds more attractive than Yodlee. The other thing I like about Plaid is that they have great documentation and provide a nice interface to Python. Intuit used to privide similar aggregation servers but it discontinued its Financial Data APIs (formerly known as CAD) in 2016. MX provides similar aggregation services, I was not able to find a free developer access from the website.
#
#
# **Open Financial Exchange(OFX) API：**
# OFX is an open standard for client-server systems and cloud based APIs for exchanging financial data. According to the main OFX site(http://www.ofx.net/), "The specification is freely licensed, allowing any software developer to design an interface that will be supported on the front-end." There are a few Python script/tool to do this, basically, you will find the right configure of your bank and download the financial data in OFX format(simliar to XML) and then parse the file. I didn't try this option out. Here is a available tutorial https://thefinancebuff.com/replacing-microsoft-money-part-5-ofx-scripts.html.
#
#
#
# Implemetation with Plaid
# ---
# I decided to go with Plaid API as it has a nice free developer access and nice technique documentations. The following section  demonstrated an approach to extract your bank transactions programmably using Python. In order to use Plaied, you  need to create an account with Plaid (https://plaid.com/). Once you have an account, choose 'Build in the Plaid Development Environment' and apply a developer API key, this may take several days to be approved. From Plaid's documentation, the development environment supports live credentials and data for every institution Plaid supports. The maximum amount of unique live credential sets that may be linked is 100. credential sets refers to the login credential you use to login to your bank's online banking site.
#
# The figure below represent a high level flow of how this worked. Plaid will extract bank transactions from your banks. Once Plaid verified a bank connection with you own online banking credential for one of your bank, then you can use a unique access token, along with the API key to download transaction for that institution. You can use the same process to download transaction from other banks that you have an account. After transactions are extracted, I stored them into a collection in MongoDB for further analaysis and modeling.

# %% [markdown]
# ![title](img/ETL.png)

# %% [markdown]
# **Get AccessToken for your bank:**
# Follow the quick start guide from Plaid (https://github.com/plaid/quickstart/tree/master/python). Note that you need to updaet your Plaid API keys (client ID, secret, public_key) in server.py. After you have successfully connected a account, go back to your command line window, and copy the access_token

# %%
from plaid import Client

# Available environments are 'sandbox', 'development', and 'production'.
client = Client(client_id='5a6017368d92397955d2f2e1', secret='89b50c98f187eb704b0dd011d3acb1', public_key='fba07e0680e3383833e5be017de25d', environment='sandbox')
# assess_token from Plaid Link
access_token='access-sandbox-74019a74-7d87-4f97-981d-134fa762c60a'

# %% [markdown]
# **Get transactions with API key and access_token:** Be aware that Plaid will not be able to get all your historical transactions. For example, I couldn't get my transactions in 2015. The amount of data come back differs from bank to bank.

# %%
response = client.Transactions.get(access_token, start_date='2013-07-12', end_date='2018-01-19')
transactions = response['transactions']

# the transactions in the response are paginated, so make multiple calls while increasing the offset to
# retrieve all transactions
while len(transactions) < response['total_transactions']:
    response = client.Transactions.get(access_token, start_date='2013-07-12', end_date='2018-01-21',
                                       offset=len(transactions)
                                      )
    transactions.extend(response['transactions'])
    
Category = client.Categories.get()

# %% [markdown]
# Below is an example transaction downloaded. It's a json format document with varies key values pairs that describe a transaction. The data points I'm interested in are name, date, amount. It indicates that I spent $14.15 at 'MR BING VANDERBILT LL' on Jan 19 2018 - It was my lunch. Note that here Plaid also returns the category. It appears for this transaction it could confidently determine the category.

# %% [markdown]
# ```json
# {
#     "account_owner": null,
#     "category": null,
#     "account_id": "4R0myMYJNwfbDJqNrnexHV3B35KVQYf0bN389",
#     "pending_transaction_id": "JjNPVdKryLILJzqdgE0vcLdPy79YqYtgwoyqv",
#     "transaction_id": "DyEdbM1kOmhbXaw0Y7gAumQ5Lx8DZRIoDv3nD",
#     "transaction_type": "unresolved",
#     "amount": 14.15,
#     "location": {
#         "city": null,
#         "zip": null,
#         "store_number": null,
#         "lon": null,
#         "state": null,
#         "address": null,
#         "lat": null
#     },
#     "payment_meta": {
#         "reference_number": null,
#         "payer": null,
#         "payment_method": null,
#         "reason": null,
#         "payee": null,
#         "ppd_id": null,
#         "payment_processor": "Square",
#         "by_order_of": null
#     },
#     "date": "2018-01-19",
#     "category_id": null,
#     "pending": false,
#     "name": "MR BING VANDERBILT LL"
# }
# ```

# %% [markdown]
# **Load the data into MongoDB:** finally, I'll dump the transactions into my local Mongo instance. It'll be more convenient to analyse and explore json data with Mongo queries.

# %%
##from json import dumps
##print dumps(transactions,indent=4)

from pymongo import MongoClient
mongoclient = MongoClient('localhost')
##Mongoclient.database_names()
db = mongoclient['bankdata']
new_result = db.transactions.insert_many(transactions)
##new_result = db.category.insert_many(Category['categories'])

# %%
transactions
# Out:
# [{u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2018-01-11',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'XWXB1aQR8LSjr47Exj41I65G4xykW5FpvzGKK',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2018-01-09',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'GDLo3pR6QrTXqPMREXP3H8xelQZ5BxfJ7rkMQ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2018-01-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'6ErdmzL4gAhexkAZDekKTb39xB6v53ijPM4DK',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2018-01-05',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'RDmoVrZA87TBxzdPqBzMC5Mez6vnlMf7or8pN',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2018-01-05',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'vnGA543JqaSm9pKRbmp8TbJVXKqnQJiaZ4r6Z',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2017-12-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'bWdg31woxbSlpeQ7gleDuxyjBPgNbycg6y8bQ',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'AE7pQe4WnDhy93AQey3jU8qjJL5NnqfRxKzrz',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2017-12-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ynm53jDRVPSGdyBzmGyoUP8gR65bw8Ck8Lx6A',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'9E3KVx5j8bhkLyA1JkyBUAQGD9758QSz9bjxg',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-12-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'WD6z8dpAR1TBNa6KWBawCB6oLygM96coQAgZn',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-12-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'8EBqw3vPpnhvq8ryAv8zudQ16EGqLQCvJ4qpd',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2017-12-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'EDMvN1nW9qTb9mGw8bmrsy6GnL9xR6CZ5vbxo',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-23',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'gWjkA8N6bRSBZPNDKBPJCVDrL1d4xDfj7aWRA',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-22',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'LDEojWQwVdTyemKpEymoUkVkQaWzVEugWvK86',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-12-12',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'1EXmyGLBlohr9JojwrJACXq8r1gjyribPLXaJ',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-10',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ZWlegNpAqoSze9Qxwz9qSRQR7dykQWtn1AmRl',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'MDWowARV7aT7mMrgn7MRSwBLaD8xvafbRwp5o',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-12-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ZWlegNpAqoSze9Qxwz9qSRQ3gXpLDgin1Amv6',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-12-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'QDbmVK7AJjT739xP879pS9L1jbDokjirl46nQ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2017-11-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'1EXmyGLBlohr9JojwrJACXqXJA97qaibPLX7P',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'QDbmVK7AJjT739xP879pS9L9M3QALJfrl46M7',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2017-11-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'kWZkbGpoyVS98QMlg9QySQMQ596zM7Hr1gDEw',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'eWN1aoyDv9Sr4vP7krvmCdePXjq31Xty3RBX9',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-11-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'eWN1aoyDv9Sr4vP7krvmCdedgr9neWiy3RBd1',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-11-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'jnQPZAk6bDSG8p7RBGpXUy1yrGog1zhoRzmMB',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2017-11-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'7DzlQBLNpGTlw9A6ml9ru9E9la6bEef4BAylK',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-23',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'PDnoeqjAbPToG93Lvo97SlMlkvEmMWFEyB5kg',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-22',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'MDWowARV7aT7mMrgn7MRSwBwlyeZBmhbRwpx1',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-11-12',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'7DzlQBLNpGTlw9A6ml9ru9EMxv8rPxi4BAyay',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-10',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'NDkgwGMyR4Terlz8ZelqT7W7jkQNWLFLABpjE',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'jnQPZAk6bDSG8p7RBGpXUy16W3mExWIoRzmjK',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-11-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'PDnoeqjAbPToG93Lvo97SlM1PV5doPFEyB5ny',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-11-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'NDkgwGMyR4Terlz8ZelqT7We465ZA4ILABpzQ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2017-10-28',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ZWlegNpAqoSze9Qxwz9qSRQR7dykQWtn1AmLl',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-28',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'45qGvKpdrEuranoyjrnlCmom5EDro8c8RNVra',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2017-10-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'JDg9a8QWE3TdzelgqdeGiAaA45wNakfpeWMj5',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'45qGvKpdrEuranoyjrnlCmoQznWRNzh8RNVKM',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-10-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'abx9dMPGenIQ83dRmQ37sogoMdZGgvIpKlJEd',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-10-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'xnb5BPRmrNSoRpzBwopESMvM4nbBvEFmKpPzd',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2017-10-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'd648dpN9wyIGJal7jGaRU979QGEA76fon5zbV',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'3AldBqLxK8iweJ16BwJQS3R31JLxRoFGVKbj7',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-23',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'QDbmVK7AJjT739xP879pS9L9M3QALJfrl46o7',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-10-13',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'abx9dMPGenIQ83dRmQ37sog7WbJ5XWCpKlJvQ',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-11',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'Bbe9lQvWRVIWNxjrBWx7hBQB8bR3Q4Fqx65p6',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-08',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'd648dpN9wyIGJal7jGaRU97WPawMVPion5zqe',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-10-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'xnb5BPRmrNSoRpzBwopESMvLDQW3aDhmKpPZR',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-10-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'3AldBqLxK8iweJ16BwJQS3RrEdQ4ZEFGVKbLB',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2017-09-28',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'eWN1aoyDv9Sr4vP7krvmCdedgr9neWiy3RBD1',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-28',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'zXy9M7A1mjT8wpymq8pKieDeG9pxD8HDXJBy8',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2017-09-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'5mK6xrJaoWsw3bAWpwbqSqgqkAXygbFzQeyV3',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'Bbe9lQvWRVIWNxjrBWx7hBQyMwLJnMCqx651r',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-09-26',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'rn89R3KoJBSQnNZAeQNwsbBbRQGnBlfLkq9AN',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-09-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'QDbmVK7AJjT739xP879pS9L9M3QALJfrl46gj',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2017-09-25',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ZWlegNpAqoSze9Qxwz9qSRQR7dykQWtn1AmEW',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-24',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'eWN1aoyDv9Sr4vP7krvmCdedgr9neWiy3RBbJ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-23',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'7DzlQBLNpGTlw9A6ml9ru9E9la6bEef4BAyQK',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2017-09-13',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'zXy9M7A1mjT8wpymq8pKieDQnol5wnfDXJBKR',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-11',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'7DzlQBLNpGTlw9A6ml9ru9E9la6bEef4BAy5j',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-08',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'rn89R3KoJBSQnNZAeQNwsbBrgqJekgCLkq9XZ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2017-09-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'KD8ZaEyWnxTalQqAEaQ4SyXpxW58JxIgDWkQw',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-09-07',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'qyg9XBqoRzceVao3Zea1TeLPBqpzRBf8yAP3p',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2017-08-29',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'jnQPZAk6bDSG8p7RBGpXUy1yrGog1zhoRzm4B',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-08-29',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'jnQPZAk6bDSG8p7RBGpXUy1yrGog1zhoRzm7G',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2017-08-28',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'wmnJANx1K4spKEyDApEeSKLK5pEWLvtA1DR9E',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2017-08-27',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
# ...
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'd648dpN9wyIGJal7jGaRU979QGEA76fon5zwE',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2016-03-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'ynm53jDRVPSGdyBzmGyoUP8PwVXA8oFk8Lndm',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-03-05',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'Bbe9lQvWRVIWNxjrBWx7hBQB8bR3Q4Fqx65y6',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2016-03-05',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'xnb5BPRmrNSoRpzBwopESMvM4nbBvEFmKpPoP',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2016-03-04',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'Bbe9lQvWRVIWNxjrBWx7hBQB8bR3Q4Fqx65Px',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2016-03-04',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'3AldBqLxK8iweJ16BwJQS3R31JLxRoFGVKbpg',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-03-03',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'zXy9M7A1mjT8wpymq8pKieDeG9pxD8HDXJB9Q',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-03-02',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'LDEojWQwVdTyemKpEymoUkVkQaWzVEugWvKQ6',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2016-02-21',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'zXy9M7A1mjT8wpymq8pKieDeG9pxD8HDXJBa8',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 6.33,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-19',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 072515 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'rn89R3KoJBSQnNZAeQNwsbBbRQGnBlfLkq9xM',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-16',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Tectra Inc',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'rn89R3KoJBSQnNZAeQNwsbBbRQGnBlfLkq9wN',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2016-02-15',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'KFC',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'KD8ZaEyWnxTalQqAEaQ4SyXyZ6d3XGhgDWk8J',
#   u'transaction_type': u'place'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 500,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-15',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Madison Bicycle Shop',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'3AldBqLxK8iweJ16BwJQS3RrEdQ4ZEFGVKbxB',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': 25,
#   u'category': [u'Payment', u'Credit Card'],
#   u'category_id': u'16001000',
#   u'date': u'2016-02-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CREDIT CARD 3333 PAYMENT *//',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'5mK6xrJaoWsw3bAWpwbqSqgqkAXygbFzQeyw3',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 5.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-06',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Uber 063015 SF**POOL**',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'KD8ZaEyWnxTalQqAEaQ4SyXyZ6d3XGhgDWkPA',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'6ErdmzL4gAhexkAZDekKTb3Awlnm7ZtjPMKWd',
#   u'account_owner': None,
#   u'amount': 1000,
#   u'category': [u'Transfer', u'Deposit'],
#   u'category_id': u'21007000',
#   u'date': u'2016-02-05',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'CD DEPOSIT .INITIAL.',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'onp9XrWo5KSje6kAKj6WIbabejGna9f4Vx59q',
#   u'transaction_type': u'special'},
#  {u'account_id': u'XWXB1aQR8LSjr47Exj41I65NvJQ9gpfpvzj4V',
#   u'account_owner': None,
#   u'amount': 78.5,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-04',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Touchstone Climbing',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'qyg9XBqoRzceVao3Zea1TeLeKEWZLjH8yAPWQ',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': -500,
#   u'category': [u'Travel', u'Airlines and Aviation Services'],
#   u'category_id': u'22001000',
#   u'date': u'2016-02-04',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'United Airlines',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'qyg9XBqoRzceVao3Zea1TeLeKEWZLjH8yAPak',
#   u'transaction_type': u'special'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 12,
#   u'category': [u'Food and Drink', u'Restaurants', u'Fast Food'],
#   u'category_id': u'13005032',
#   u'date': u'2016-02-03',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': u'3322',
#    u'zip': None},
#   u'name': u"McDonald's",
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'd648dpN9wyIGJal7jGaRU979QGEA76fon5zkP',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 4.33,
#   u'category': [u'Food and Drink', u'Restaurants', u'Coffee Shop'],
#   u'category_id': u'13005043',
#   u'date': u'2016-02-03',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'Starbucks',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'lnMdWlJoZwS4eADkB4AXUl7l34Gj7BF1mGgye',
#   u'transaction_type': u'place'},
#  {u'account_id': u'vnGA543JqaSm9pKRbmp8TbJDw3EvMetaZ4e3y',
#   u'account_owner': None,
#   u'amount': 89.4,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-02',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'SparkFun',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'kWZkbGpoyVS98QMlg9QySQMQ596zM7Hr1gDBX',
#   u'transaction_type': u'unresolved'},
#  {u'account_id': u'RDmoVrZA87TBxzdPqBzMC5MW4mdAjgi7orkvd',
#   u'account_owner': None,
#   u'amount': -4.22,
#   u'category': None,
#   u'category_id': None,
#   u'date': u'2016-02-01',
#   u'location': {u'address': None,
#    u'city': None,
#    u'lat': None,
#    u'lon': None,
#    u'state': None,
#    u'store_number': None,
#    u'zip': None},
#   u'name': u'INTRST PYMNT',
#   u'payment_meta': {u'by_order_of': None,
#    u'payee': None,
#    u'payer': None,
#    u'payment_method': None,
#    u'payment_processor': None,
#    u'ppd_id': None,
#    u'reason': None,
#    u'reference_number': None},
#   u'pending': False,
#   u'pending_transaction_id': None,
#   u'transaction_id': u'1EXmyGLBlohr9JojwrJACXqXJA97qaibPLXKP',
#   u'transaction_type': u'unresolved'}]

# %%
from pymongo import MongoClient
mongoclient = MongoClient('localhost')
##Mongoclient.database_names()
db = mongoclient['bankdata']
new_result = db.transactions_fake.insert_many(transactions)
##new_result = db.category.insert_many(Category['categories'])
